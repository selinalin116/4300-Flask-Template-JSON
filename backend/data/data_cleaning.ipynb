# %%
import pandas as pd
import zipfile

# %% [markdown]
# We can probably remove id, serving size, and tags.

# %%
recipes = pd.read_csv("recipes_w_search_terms.csv")
recipes.head()
# Out:
#        id                                   name  \
# 0   96313            Grilled Garlic Cheese Grits
# 1  232037  Simple Shrimp and Andouille Jambalaya
# 2   41090             black-and-white bean salad
# 3   60656             Crock Pot Italian Zucchini
# 4  232047          Beef Stew With Dried Cherries
#
#                                          description  \
# 0  We love grits, this is another good way to ser...
# 1  Simple, easy and very tasty for when you are i...
# 2                                                NaN
# 3  This is a good recipe for weight watchers. It ...
# 4  This is a fabulous stew that came from one of ...
#
#                                          ingredients  \
# 0  ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1  ['onion', 'red bell pepper', 'garlic cloves', ...
# 2  ['white beans', 'canned black beans', 'tomatoe...
# 3  ['zucchini', 'yellow squash', 'diced tomatoes'...
# 4  ['beef stew meat', 'flour', 'salt', 'allspice'...
#
# ...

# %%
cleaned = recipes.drop(["id","serving_size","tags"], axis=1, inplace=False)
cleaned = cleaned[(cleaned['name'].str.count(' ') < 3) & (cleaned['description'].notna())]
cleaned.head()
# Out:
#                    name                                        description  \
# 8   Potato-Crab Chowder                                 Soup for the soul!
# 12      Steak Au Poivre             An American-French restaurant classic.
# 13     Mushroom Ravioli  From Cooking Light, with slight midifications....
# 21        Ras El Hanout  There are as many different recipes for this a...
# 26   Chocolate Biscuits  This is from  Small Cakes and Cookies cookbook...
#
#                                           ingredients  \
# 8   ['butter', 'onion', 'garlic', 'potatoes', 'flo...
# 12  ['unsalted beef stock', 'onion', 'carrot', 'ba...
# 13  ['button mushrooms', 'portabella mushrooms', '...
# 21  ['coriander', 'ginger', 'cardamom', 'cumin', '...
# 26  ['self rising flour', 'butter', 'superfine sug...
#
#                                   ingredients_raw_str  servings  \
# 8   ["2   tablespoons    butter","1   medium    on...         6
# ...

# %%
cleaned.to_json('recipes_cleaned.json', orient='records')

# %%
names = recipes['name']
print(len(names))
names.to_csv('recipes_names.csv', index=False)
# Out:
# 231605
